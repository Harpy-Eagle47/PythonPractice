# %%
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

digits = load_digits()

# %%
X_train, X_test, y_train, y_test = train_test_split(digits.data, digits.target)

model = KNeighborsClassifier()

model.fit(X_train, y_train)

print(model.score(X_test, y_test))
# Out:
# 0.9866666666666667

# %%
model.predict([digits.data[5]])

print([digits.data[5]])
# Out:
# [array([ 0.,  0., 12., 10.,  0.,  0.,  0.,  0.,  0.,  0., 14., 16., 16.,
#        14.,  0.,  0.,  0.,  0., 13., 16., 15., 10.,  1.,  0.,  0.,  0.,
#        11., 16., 16.,  7.,  0.,  0.,  0.,  0.,  0.,  4.,  7., 16.,  7.,
#         0.,  0.,  0.,  0.,  0.,  4., 16.,  9.,  0.,  0.,  0.,  5.,  4.,
#        12., 16.,  4.,  0.,  0.,  0.,  9., 16., 16., 10.,  0.,  0.])]

# %%
from sklearn.linear_model import LogisticRegression

model2 = LogisticRegression(max_iter=1000)

model2.fit(X_train, y_train)

print(model2.score(X_test, y_test))
# Out:
# 0.9555555555555556

# %%
from sklearn.ensemble import RandomForestClassifier

model3 = RandomForestClassifier()

model3.fit(X_train, y_train)

print(model3.score(X_test, y_test))
# Out:
# 0.9755555555555555

# %%
from sklearn.tree import DecisionTreeClassifier

list = [1, 2, 5, 10, 20, None]

for depth in list:
  model4 = DecisionTreeClassifier(max_depth=depth)

  model4.fit(X_train, y_train)

  print(str(depth) + " depth")
  print(str(model4.score(X_train,y_train)) + " train")
  print(str(model4.score(X_test,y_test)) + " test")
# Out:
# 1 depth
# 0.20935412026726058 train
# 0.1622222222222222 test
# 2 depth
# 0.37639198218262804 train
# 0.3466666666666667 test
# 5 depth
# 0.7564959168522642 train
# 0.6888888888888889 test
# 10 depth
# 0.9829250185597624 train
# 0.8466666666666667 test
# 20 depth
# 1.0 train
# 0.8533333333333334 test
# None depth
# 1.0 train
# 0.8555555555555555 test

# %%
import time

startTime = time.time()

model.predict([X_test[10]])

endTime = time.time()

print(str(endTime - startTime))
# Out:
# 0.004605293273925781

# %%
model4 = DecisionTreeClassifier(max_depth=None)

model4.fit(X_train, y_train)

startTime = time.time()

model4.predict([X_test[10]])

endTime = time.time()

print(str(endTime - startTime))
# Out:
# 0.0010960102081298828
