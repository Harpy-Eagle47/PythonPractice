# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
from google.colab.patches import cv2_imshow

doggo = cv2.imread("/content/drive/MyDrive/ColabNotebooks/Practice/doggo.png")

cv2_imshow(doggo)

print(doggo.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=736x674>
# (674, 736, 3)

# %%
smallDoggo = cv2.resize(doggo, (300,184))

cv2_imshow(smallDoggo)
# Out:
# <PIL.Image.Image image mode=RGB size=300x184>

# %%
red = cv2.imread("/content/drive/MyDrive/ColabNotebooks/Practice/red2.png")

cv2_imshow(red)

print(red.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=66x64>
# (64, 66, 3)

# %%
snowman = cv2.imread("/content/drive/MyDrive/ColabNotebooks/Practice/snowman.png")

cv2_imshow(snowman)

print(snowman.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=660x440>
# (440, 660, 3)

# %%
lilSnowman = cv2.resize(snowman, (66,44))

cv2_imshow(lilSnowman)
# Out:
# <PIL.Image.Image image mode=RGB size=66x44>

# %%
justSnowman = snowman[0:440,310:620]

cv2_imshow(justSnowman)

cv2.imwrite("/content/drive/MyDrive/ColabNotebooks/Practice/lilsnowman.png",justSnowman)
# Out:
# <PIL.Image.Image image mode=RGB size=310x440>
# True

# %%
alpacas = cv2.imread("/content/drive/MyDrive/ColabNotebooks/Practice/alpacagroup.png")

cv2_imshow(alpacas)

print(alpacas.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=374x267>
# (267, 374, 3)

# %%
smallAlpacas = cv2.resize(alpacas,(274,167))

cv2_imshow(smallAlpacas)

print(smallAlpacas.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=274x167>
# (167, 274, 3)

# %%
these2Alpacas = smallAlpacas[0:274,60:167]

cv2_imshow(these2Alpacas)

cv2.imwrite("/content/drive/MyDrive/ColabNotebooks/Practice/these2Alpacas.jpg",these2Alpacas)
# Out:
# <PIL.Image.Image image mode=RGB size=107x167>
# True
